# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('brain_stroke.csv')
data.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1    Male  80.0             0              1          Yes        Private
# 2  Female  49.0             0              0          Yes        Private
# 3  Female  79.0             1              0          Yes  Self-employed
# 4    Male  81.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             105.92  32.5     never smoked       1
# 2          Urban             171.23  34.4           smokes       1
# 3          Rural             174.12  24.0     never smoked       1
# 4          Urban             186.21  29.0  formerly smoked       1

# %%
data.describe().T
# Out:
#                     count        mean        std    min    25%    50%     75%  \
# age                4981.0   43.419859  22.662755   0.08  25.00  45.00   61.00
# hypertension       4981.0    0.096165   0.294848   0.00   0.00   0.00    0.00
# heart_disease      4981.0    0.055210   0.228412   0.00   0.00   0.00    0.00
# avg_glucose_level  4981.0  105.943562  45.075373  55.12  77.23  91.85  113.86
# bmi                4981.0   28.498173   6.790464  14.00  23.70  28.10   32.60
# stroke             4981.0    0.049789   0.217531   0.00   0.00   0.00    0.00
#
#                       max
# age                 82.00
# hypertension         1.00
# heart_disease        1.00
# avg_glucose_level  271.74
# bmi                 48.90
# stroke               1.00

# %%
n_data = data.dropna()

# %%
n_data.value_counts
# Out:
# <bound method DataFrame.value_counts of       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
# ...

# %% [markdown]
# encoding process

# %%
# x = pd.DataFrame(data)
# x['gender'] = [1 if x == 'Male' else 0 for x in x['gender']]
# x['ever_married'] = [1 if x == 'Yes' else 0 for x in x['ever_married']]
# x['work_type'] = [1 if x == 'Private' else 2 if x == 'Self-employed' else 3 if x == 'children' else 0 for x in x['work_type']]
# x['Residence_type'] = [1 if x == 'Yes' else 0 for x in x['Residence_type']]
# x['smoking_status'] = [1 if x == 'never smoked' else 2 if x == 'Unknown' else 3 if x == 'formerly smoked' else 0 for x in x['smoking_status']]

# %%
groups = n_data[['gender', 'stroke']]
grouped_data = groups.groupby('gender')['stroke'].mean()
grouped_data = grouped_data.sort_values()

fig, ax = plt.subplots(figsize=(16,10), dpi=80)
sns.barplot(x=grouped_data.index, y=grouped_data.values,hue=grouped_data, order=grouped_data.index)
ax.set_title("Gender VS. Stroke", size=20)
ax.set_xlabel('gender', size=20)
ax.set_ylabel('AVG No. of stroke', size=20)
ax.set_xticks(ticks=range(len(grouped_data)),labels=grouped_data.index, size=20)

# %%
groups = n_data[['hypertension', 'stroke']]
grouped_data = groups.groupby('hypertension')['stroke'].mean()
grouped_data = grouped_data.sort_values()

fig, ax = plt.subplots(figsize=(16,10), dpi=80)
sns.barplot(x=grouped_data.index, y=grouped_data.values,hue=grouped_data, order=grouped_data.index)
ax.set_title("hypertension VS. Stroke", size=20)
ax.set_xlabel('hypertension', size=20)
ax.set_ylabel('AVG No. of stroke', size=20)
ax.set_xticks(ticks=range(len(grouped_data)),labels=grouped_data.index, size=20)

# %%
groups = n_data[['heart_disease', 'stroke']]
grouped_data = groups.groupby('heart_disease')['stroke'].mean()
grouped_data = grouped_data.sort_values()

fig, ax = plt.subplots(figsize=(16,10), dpi=80)
sns.barplot(x=grouped_data.index, y=grouped_data.values,hue=grouped_data, order=grouped_data.index)
ax.set_title("heart_disease VS. Stroke", size=20)
ax.set_xlabel('heart_disease', size=20)
ax.set_ylabel('AVG No. of stroke', size=20)
ax.set_xticks(ticks=range(len(grouped_data)),labels=grouped_data.index, size=20)

# %%
groups = n_data[['ever_married', 'stroke']]
grouped_data = groups.groupby('ever_married')['stroke'].mean()
grouped_data = grouped_data.sort_values()

fig, ax = plt.subplots(figsize=(16,10), dpi=80)
sns.barplot(x=grouped_data.index, y=grouped_data.values,hue=grouped_data, order=grouped_data.index)
ax.set_title("ever_married VS. Stroke", size=20)
ax.set_xlabel('ever_married', size=20)
ax.set_ylabel('AVG No. of stroke', size=20)
ax.set_xticks(ticks=range(len(grouped_data)),labels=grouped_data.index, size=20)

# %%
groups = n_data[['work_type', 'stroke']]
grouped_data = groups.groupby('work_type')['stroke'].mean()
grouped_data = grouped_data.sort_values()

fig, ax = plt.subplots(figsize=(16,10), dpi=80)
sns.barplot(x=grouped_data.index, y=grouped_data.values,hue=grouped_data, order=grouped_data.index)
ax.set_title("work_type VS. Stroke", size=20)
ax.set_xlabel('work_type', size=20)
ax.set_ylabel('AVG No. of stroke', size=20)
ax.set_xticks(ticks=range(len(grouped_data)),labels=grouped_data.index, size=20)

# %%
groups = n_data[['Residence_type', 'stroke']]
grouped_data = groups.groupby('Residence_type')['stroke'].mean()
grouped_data = grouped_data.sort_values()

fig, ax = plt.subplots(figsize=(16,10), dpi=80)
sns.barplot(x=grouped_data.index, y=grouped_data.values,hue=grouped_data, order=grouped_data.index)
ax.set_title("Residence_type VS. Stroke", size=20)
ax.set_xlabel('Residence_type', size=20)
ax.set_ylabel('AVG No. of stroke', size=20)
ax.set_xticks(ticks=range(len(grouped_data)),labels=grouped_data.index, size=20)

# %%
x= n_data.drop(columns=['stroke'])
y= n_data['stroke']

# %%
from category_encoders import BinaryEncoder
categorical_features = ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']

encoder = BinaryEncoder()
x_encoded = encoder.fit_transform(x[categorical_features])

# Drop and replace
x = x.drop(categorical_features, axis=1)
x = x.reset_index(drop=True)
x_encoded = x_encoded.reset_index(drop=True)
x = pd.concat([x, x_encoded], axis=1)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=.25, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
dcs = DecisionTreeClassifier()
dcs.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# from sklearn.metrics import (
#   accuracy_score,
#   precision_score
# )
# prediction = dcs.predict(x_test)
# accuracy = accuracy_score(prediction, y_test)
# precision = precision_score(y_test, prediction)

# print(f"accuracy:{accuracy * 100}")
# print(f"precision : {precision * 100}")

# %%
n_prediction = dcs.predict(x_test.head(1))
x_test.head(1)
# Out:
#        age  hypertension  heart_disease  avg_glucose_level   bmi  gender_0  \
# 1129  65.0             1              0             180.76  26.9         1
#
#       gender_1  ever_married_0  ever_married_1  work_type_0  work_type_1  \
# 1129         0               0               1            0            0
#
#       work_type_2  Residence_type_0  Residence_type_1  smoking_status_0  \
# 1129            1                 0                 1                 1
#
#       smoking_status_1  smoking_status_2
# 1129                 0                 0

# %%
# from sklearn.model_selection import train_test_split
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=.25, random_state=43)

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE()
x, y = smote.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# stroke
# 1    4733
# 0    4733
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier

# Standardize the data
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)


dcs = DecisionTreeClassifier(random_state=42)
dcs.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

smote = SMOTE(random_state=42)
x_resampled, y_resampled = smote.fit_resample(x, y)


x_train, x_test, y_train, y_test = train_test_split(x_resampled, y_resampled, test_size=0.2, random_state=42)

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

dcs = DecisionTreeClassifier(random_state=42)
dcs.fit(x_train, y_train)


dcs_prediction = dcs.predict(x_test)

dcs_accuracy = accuracy_score(y_test, dcs_prediction)
dcs_precision = precision_score(y_test, dcs_prediction)


print(f" Accuracy: {dcs_accuracy * 100:.2f}%")
print(f" Precision: {dcs_precision * 100:.2f}%")
# Out:
#  Accuracy: 93.82%
#  Precision: 94.16%

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz
import graphviz
import joblib
import pandas as pd

feature_names = x.columns  

dcs = DecisionTreeClassifier()
dcs.fit(x_train, y_train)

# Fix the feature_names issue
export_graphviz(dcs, out_file='tree.dot', filled=True, feature_names=feature_names)

# Read and visualize the tree
with open('tree.dot') as f:
    dot_graph = f.read()

graphviz.Source(dot_graph)

# Save the model
# joblib.dump(dcs, "decision_tree_model.joblib")

# %%
from joblib import load

loaded_model = load("decision_tree_model.joblib")
prediction = loaded_model.predict(x_test)
